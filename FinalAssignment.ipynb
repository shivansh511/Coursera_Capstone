# %% [markdown]
# # Introduction

# %% [markdown]
# New York city is a very diverse and a financial capital of it's country, USA. There are five boroughs, Bronx, Manhattan, Brooklyn, Queens, Staten Island, in NY city and those boroughs have nearly 306 neighborhoods. Queens has 81 of total neighborhoods in NY city and these 81 neighborhoods have 261 venues for restaurant, gyms, schools, market shops and various other places. <br>
# Now if someone wants to open a reataurant, where in Queens, NY he should look forward to opening it in order to attract more customers? And what kind of restaurant should it be? And what other services can he/she look forward.

# %% [markdown]
# ### Data

# %% [markdown]
# The data for all the boroughs and neighborhoods along with their coordinates, of New York city was provided to me in json format for an assignment I had submitted earlier. Link to the json file is [here](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/labs/newyork_data.json)

# %% [markdown]
# My main focus will be Queens, NY and all the data about the venues and their locations can be extracted from [https://foursquare.com.](https://foursquare.com)
