# %% [markdown]
# # Capstone

# %% [markdown]
# This notebook is mainly for coursera course on Applied Data Science Capstone.

# %%
import numpy as np
import pandas as pd

# %%
print('Hellooo!!! Applied Data Science Capstone')
# Out:
# Hellooo!!! Applied Data Science Capstone
